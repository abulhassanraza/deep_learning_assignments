# %% [markdown]
# <a href="https://colab.research.google.com/github/abulhassanraza/deep_learning_assignments/blob/main/Ionosphere_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from keras.layers import Dense

# %%
data = pd.read_csv('ionosphere_data.csv')

# %%
data.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
data.isna().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
data.describe()
# Out:
#          feature1  feature2    feature3  ...   feature32   feature33   feature34
# count  351.000000     351.0  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342  ...   -0.003794    0.349364    0.014480
# std      0.311155       0.0    0.497708  ...    0.513574    0.522663    0.468337
# min      0.000000       0.0   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000       0.0    0.871110  ...    0.000000    0.409560    0.000000
# 75%      1.000000       0.0    1.000000  ...    0.200120    0.813765    0.171660
# max      1.000000       0.0    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 34 columns]

# %%
data.drop(columns='feature2', inplace=True)

# %%
data.label.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      g
# 1      b
# 2      g
# 3      b
# 4      g
#       ..
# 346    g
# 347    g
# 348    g
# 349    g
# 350    g
# Name: label, Length: 351, dtype: object>

# %%
encoded_values = {'label': {'g':0, 'b':1}}

# %%
df = data.replace(encoded_values)

# %%
y = df.label
x = df.drop(columns='label')

# %%
df.head()
# Out:
#    feature1  feature3  feature4  ...  feature33  feature34  label
# 0         1   0.99539  -0.05889  ...    0.18641   -0.45300      0
# 1         1   1.00000  -0.18829  ...   -0.13738   -0.02447      1
# 2         1   1.00000  -0.03365  ...    0.56045   -0.38238      0
# 3         1   1.00000  -0.45161  ...   -0.32382    1.00000      1
# 4         1   1.00000  -0.02401  ...   -0.04608   -0.65697      0
#
# [5 rows x 34 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 346    0
# 347    0
# 348    0
# 349    0
# 350    0
# Name: label, Length: 351, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.40)

# %%
x_train
# Out:
#      feature1  feature3  feature4  ...  feature32  feature33  feature34
# 89          1   0.41932   0.12482  ...   -0.07464   -0.00526   -0.06314
# 180         1   1.00000   1.00000  ...    0.20175    0.82895    0.07895
# 35          1   0.66161  -1.00000  ...    0.65268    1.00000    0.34732
# 96          1   0.90116   0.16607  ...   -0.05525   -0.67699   -0.19904
# 213         1   1.00000   0.14286  ...    0.57143    1.00000    0.00000
# ..        ...       ...       ...  ...        ...        ...        ...
# 142         1   1.00000  -0.05529  ...   -0.63156    1.00000   -0.65935
# 118         1   0.39286   0.52381  ...   -0.29915    0.25441   -0.55837
# 7           0   0.00000   0.00000  ...    1.00000    0.00000    0.00000
# 266         1   0.76627   0.21106  ...   -0.24648   -0.11894   -0.27218
# 263         1   0.89410   0.13425  ...    0.19172   -0.48808    0.05972
#
# [210 rows x 33 columns]

# %%
y_train
# Out:
# 89     1
# 180    1
# 35     1
# 96     0
# 213    0
#       ..
# 142    1
# 118    1
# 7      1
# 266    0
# 263    0
# Name: label, Length: 210, dtype: int64

# %%
from keras.models import Sequential
from keras import regularizers

# %%
model = Sequential()
model.add(Dense(14, activation= 'sigmoid',input_shape= (33,)))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='Adam', loss= 'binary_crossentropy', metrics= 'accuracy')

# %%
model.fit(x_train, y_train, epochs= 100, batch_size= 8)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 1ms/step - loss: 0.6839 - accuracy: 0.5339
# Epoch 2/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6114 - accuracy: 0.6547
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.7035
# Epoch 4/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5990 - accuracy: 0.6821
# Epoch 5/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6020 - accuracy: 0.6650
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5876 - accuracy: 0.6861
# Epoch 7/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5536 - accuracy: 0.7050
# Epoch 8/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5300 - accuracy: 0.7511
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.7273
# Epoch 10/100
# ...

# %%
prediction = model.predict(x_test)

# %%
model.evaluate(x_test, y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8156
# [0.40811166167259216, 0.8156028389930725]

# %%
prediction.shape
# Out:
# (141, 1)

# %%
prediction.reshape(141)
# Out:
# array([0.37448806, 0.02285525, 0.8066006 , 0.04351759, 0.78342247,
#        0.015279  , 0.9699738 , 0.09765241, 0.99724996, 0.05472648,
#        0.9888878 , 0.05681083, 0.04185748, 0.04626781, 0.96995795,
#        0.25845712, 0.03683257, 0.04570684, 0.7446084 , 0.9637363 ,
#        0.11368978, 0.8754569 , 0.01988894, 0.08148116, 0.07316643,
#        0.93228376, 0.24436098, 0.9717657 , 0.12102377, 0.33986136,
#        0.80181366, 0.99185276, 0.08770078, 0.07672006, 0.0332197 ,
#        0.11712709, 0.04152387, 0.02822325, 0.3673888 , 0.05039257,
#        0.0341754 , 0.04270598, 0.12811676, 0.05829376, 0.56465364,
#        0.7231002 , 0.07174698, 0.04296076, 0.04314098, 0.2253454 ,
#        0.06040776, 0.21006331, 0.27071053, 0.9526484 , 0.9196353 ,
#        0.9863425 , 0.9477744 , 0.04950047, 0.4966357 , 0.02200487,
#        0.04805487, 0.05682066, 0.03395674, 0.02553618, 0.26207906,
#        0.8001653 , 0.07209304, 0.1070565 , 0.04003739, 0.093961  ,
# ...
